# %% [markdown]
# # Code to Solve Questions 13.1 and 13.2 from Machine Learning Refined

# %%
# functions for analysis and plotting picked out and adapted from Machine Learning Refined libraries (https://github.com/jermwatt/machine_learning_refined)
from utils import *
from history_plotters import *

# import basic plotting mechanisms
import matplotlib.pyplot as plt
from matplotlib import gridspec

# This is needed to compensate for %matplotlib notebook's tendancy to blow up images when plotted inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True
# %matplotlib notebook

# autoreload function - so if anything behind the scenes is changeed those changes
# are reflected in the notebook without having to restart the kernel
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Question 13.1

# %%
# load data for first problem (pull from https://github.com/jermwatt/machine_learning_refined)
data = np.loadtxt('2_eggs.csv', delimiter=',')

x = data[:2, :]
y = data[2, :][np.newaxis, :]

# %%
# normalize x
x_means = np.mean(x, axis = 1)[:, np.newaxis] # column means with output put into column vector
x_stds = np.std(x, axis = 1)[:, np.newaxis] # column std with output put into column vector 

x = (x - x_means) / x_stds

# %%
# set up network
N = 2  # dimension of input
M = 1  # dimension of output
U_1 = 10; U_2 = 10; U_3 = 10; U_4 = 10;  # number of units per hidden layer

# the list defines our network architecture
layer_sizes = [N, U_1, U_2, U_3, U_4, M]

# generate initial weights for our network
w = initialize_network_weights(layer_sizes, scale = 0.5)

# %%
# basic parameters for gradient descent run (default algorithm)
max_its = 5000; 
alpha_choice = 10**(-1);

# %%
# run gradient descent (using the most simple gradient descent)
weight_history, train_cost_history, val_cost_history = gradient_descent(softmax, w, x, y, x, y, alpha_choice, max_its)

# %%
# calculate percent correctly classifed at each step of gradient descent
train_accuracy_history = [accuracy_2_classes(v,x,y) for v in weight_history]
val_accuracy_history = [accuracy_2_classes(v,x,y) for v in weight_history]

# put histories into arrays to make compatible with history_plotters (from the textbook GitHub)
train_cost_history = [train_cost_history];
val_cost_history = [val_cost_history];
train_accuracy_history = [train_accuracy_history];
val_accuracy_history = [val_accuracy_history];

# %%
# plot using plotting function from textbook's github page
Setup(train_cost_history, train_accuracy_history, val_cost_history, val_accuracy_history, 0)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Question 13.2

# %%
# load data for second problem (pull from https://github.com/jermwatt/machine_learning_refined)
data = np.loadtxt('3_layercake_data.csv', delimiter=',')

x = data[:2, :]
y = data[2, :][np.newaxis, :]
# Out:
# (1, 110)

# %%
# normalize x
x_means = np.mean(x, axis = 1)[:, np.newaxis] # column means with output put into column vector
x_stds = np.std(x, axis = 1)[:, np.newaxis] # column std with output put into column vector 

x = (x - x_means) / x_stds

# %%
# set up network
N = 2  # dimension of input
M = 3  # dimension of output
U_1 = 12; U_2 = 5; # number of units per hidden layer

# the list defines our network architecture
layer_sizes = [N, U_1, U_2, M]

# generate initial weights for our network
w = initialize_network_weights(layer_sizes, scale = 0.5)

# %%
# basic parameters for gradient descent run (default algorithm)
max_its = 5000;
alpha_choice = 10**(-1);

# %%
# run gradient descent
weight_history, train_cost_history, val_cost_history = gradient_descent(multiclass_softmax, w, x, y, x, y, alpha_choice, max_its)

# %%
# calculate percent correctly classifed at each step of gradient descent
train_accuracy_history = [accuracy_3_classes(v,x,y) for v in weight_history]
val_accuracy_history = [accuracy_3_classes(v,x,y) for v in weight_history]

# put histories into arrays to make compatible with history_plotters (from the textbook GitHub)
train_cost_history = [train_cost_history];
val_cost_history = [val_cost_history];
train_accuracy_history = [train_accuracy_history];
val_accuracy_history = [val_accuracy_history];

# %%
# plot using plotting function from textbook's github page
Setup(train_cost_history, train_accuracy_history, val_cost_history, val_accuracy_history,0)
# Out:
# <img src="data:image/png;base64,..." width="1000">
